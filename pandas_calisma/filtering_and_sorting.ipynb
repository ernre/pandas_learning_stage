# %%
import pandas as pd

# %%
df = pd.read_csv("gym_members_exercise_tracking.csv")

# %%
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
gender_filtered = df['Gender'] == 'Male'

# %%
df[gender_filtered]
# Out:
#      Age Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56   Male         88.3        1.71      180      157           60
# 3     25   Male         53.2        1.70      190      164           56
# 4     38   Male         46.1        1.79      188      158           68
# 6     36   Male         70.3        1.72      174      169           73
# 8     28   Male        121.7        1.94      185      127           52
# ..   ...    ...          ...         ...      ...      ...          ...
# 967   20   Male         55.0        1.60      172      168           67
# 968   24   Male         87.1        1.74      187      158           67
# 969   25   Male         66.6        1.61      184      166           56
# 971   32   Male        126.4        1.83      198      146           62
# 972   46   Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df[df['Gender'] == 'Male'] #aynı şey
# Out:
#      Age Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56   Male         88.3        1.71      180      157           60
# 3     25   Male         53.2        1.70      190      164           56
# 4     38   Male         46.1        1.79      188      158           68
# 6     36   Male         70.3        1.72      174      169           73
# 8     28   Male        121.7        1.94      185      127           52
# ..   ...    ...          ...         ...      ...      ...          ...
# 967   20   Male         55.0        1.60      172      168           67
# 968   24   Male         87.1        1.74      187      158           67
# 969   25   Male         66.6        1.61      184      166           56
# 971   32   Male        126.4        1.83      198      146           62
# 972   46   Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df[df['Workout_Type'] == 'Strength']
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# 8     28    Male        121.7        1.94      185      127           52
# 15    39  Female         42.5        1.75      181      131           52
# 18    47  Female         66.8        1.75      199      146           56
# ..   ...     ...          ...         ...      ...      ...          ...
# 955   32    Male        102.8        1.98      168      120           61
# 959   50    Male         95.4        1.61      173      133           50
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df[(df["Workout_Type"] == "Strength") | (df["Gender"] == "Male")]
# Out:
#      Age Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56   Male         88.3        1.71      180      157           60
# 3     25   Male         53.2        1.70      190      164           56
# 4     38   Male         46.1        1.79      188      158           68
# 6     36   Male         70.3        1.72      174      169           73
# 8     28   Male        121.7        1.94      185      127           52
# ..   ...    ...          ...         ...      ...      ...          ...
# 967   20   Male         55.0        1.60      172      168           67
# 968   24   Male         87.1        1.74      187      158           67
# 969   25   Male         66.6        1.61      184      166           56
# 971   32   Male        126.4        1.83      198      146           62
# 972   46   Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df[~(df["Workout_Type"] == "Yoga")]
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# 5     56  Female         58.0        1.68      168      156           74
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df[(df["Workout_Type"] != "Yoga")] #SQL'de de ! işareti kullanıldığı için ve algoritmik olarak daha kısa sürede işlem yaptığı için ! kullanmak ~ kullanmaktan daha mantıklıdır
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# 5     56  Female         58.0        1.68      168      156           74
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df [df["Workout_Type"].isin( ["Cardio", "Strength", "Yoga"])] #tek tek and and and ile yazmak yerine isin yapusu kullanılabilir
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# 6     36    Male         70.3        1.72      174      169           73
# ..   ...     ...          ...         ...      ...      ...          ...
# 967   20    Male         55.0        1.60      172      168           67
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df [df["Workout_Type"].str.contains("th")]
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# 8     28    Male        121.7        1.94      185      127           52
# 15    39  Female         42.5        1.75      181      131           52
# 18    47  Female         66.8        1.75      199      146           56
# ..   ...     ...          ...         ...      ...      ...          ...
# 955   32    Male        102.8        1.98      168      120           61
# 959   50    Male         95.4        1.61      173      133           50
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df [df["Workout_Type"].str.contains("th", na=False)] #na= True olursa None veya <NA> değerlerini de alır. False olursa es geçer
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# 8     28    Male        121.7        1.94      185      127           52
# 15    39  Female         42.5        1.75      181      131           52
# 18    47  Female         66.8        1.75      199      146           56
# ..   ...     ...          ...         ...      ...      ...          ...
# 955   32    Male        102.8        1.98      168      120           61
# 959   50    Male         95.4        1.61      173      133           50
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df [(df["Age"] >= 30) & (df["Age"] <= 50)]
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 4     38    Male         46.1        1.79      188      158           68
# 6     36    Male         70.3        1.72      174      169           73
# 7     40  Female         69.7        1.51      189      141           64
# ..   ...     ...          ...         ...      ...      ...          ...
# 958   34  Female         66.5        1.69      191      157           52
# 959   50    Male         95.4        1.61      173      133           50
# 961   31  Female         66.6        1.67      184      137           71
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df.sort_values("Age") #eğer none veri varsa en sona sıralar
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 771   18  Female         57.2        1.75      193      160           74
# 85    18  Female         54.8        1.68      176      158           71
# 884   18    Male        114.5        1.97      192      128           60
# 353   18  Female         72.7        1.55      172      125           56
# 80    18  Female         52.3        1.74      187      165           58
# ..   ...     ...          ...         ...      ...      ...          ...
# 95    59  Female         54.6        1.57      164      169           64
# 128   59    Male        122.3        1.89      178      153           51
# 56    59  Female         65.5        1.52      161      162           61
# 943   59    Male         85.5        1.67      190      144           71
# 27    59    Male         53.9        1.75      168      135           69
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df.sort_values("Age", ascending = False) #büyükten küçüğe sıralama
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 970   59  Female         60.4        1.76      194      120           53
# 943   59    Male         85.5        1.67      190      144           71
# 27    59    Male         53.9        1.75      168      135           69
# 833   59    Male        126.4        1.69      168      149           68
# 767   59  Female         75.8        1.77      167      128           53
# ..   ...     ...          ...         ...      ...      ...          ...
# 563   18  Female         65.3        1.55      184      161           59
# 158   18    Male         70.0        1.61      173      168           71
# 904   18  Female         66.9        1.75      170      122           61
# 924   18    Male        118.6        1.64      188      134           67
# 113   18    Male         87.6        1.93      161      139           72
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df.nlargest(10, 'Calories_Burned')
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 910   32    Male         89.8        1.92      199      168           67
# 712   19    Male         82.4        1.96      174      169           62
# 511   39    Male         86.2        1.82      191      160           72
# 124   26    Male         86.2        1.68      189      157           72
# 90    25    Male         81.5        1.61      170      159           63
# 646   22    Male         88.5        1.62      174      162           69
# 572   36    Male         88.0        1.71      185      160           73
# 728   47    Male         87.2        1.64      177      165           50
# 99    24  Female         60.1        1.79      170      165           63
# 475   27    Male         89.3        1.64      192      162           64
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 910                      1.93           1783.0     Strength            10.6
# ...

# %%
df.nsmallest(10, "Calories_Burned")
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 650   47  Female         43.4        1.62      179      132           64
# 742   23  Female         64.5        1.70      187      125           72
# 619   25  Female         77.7        1.55      184      120           52
# 569   53    Male         61.0        1.63      170      124           74
# 298   50    Male        101.7        1.67      192      127           57
# 647   42    Male         73.5        1.63      188      136           68
# 259   53    Male        125.1        1.91      171      137           70
# 604   37  Female         73.5        1.69      174      131           66
# 965   23  Female         44.1        1.62      196      122           58
# 157   50  Female         67.1        1.75      161      120           59
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 650                      0.51            303.0       Cardio            25.3
# ...

# %%
df = df.nsmallest(10, "Calories_Burned")

# %%
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 650   47  Female         43.4        1.62      179      132           64
# 742   23  Female         64.5        1.70      187      125           72
# 619   25  Female         77.7        1.55      184      120           52
# 569   53    Male         61.0        1.63      170      124           74
# 298   50    Male        101.7        1.67      192      127           57
# 647   42    Male         73.5        1.63      188      136           68
# 259   53    Male        125.1        1.91      171      137           70
# 604   37  Female         73.5        1.69      174      131           66
# 965   23  Female         44.1        1.62      196      122           58
# 157   50  Female         67.1        1.75      161      120           59
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 650                      0.51            303.0       Cardio            25.3
# ...

# %%
df.reset_index() #eski data frame'den kalma satırları yeniden indexler
# Out:
#    index  Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0    650   47  Female         43.4        1.62      179      132           64
# 1    742   23  Female         64.5        1.70      187      125           72
# 2    619   25  Female         77.7        1.55      184      120           52
# 3    569   53    Male         61.0        1.63      170      124           74
# 4    298   50    Male        101.7        1.67      192      127           57
# 5    647   42    Male         73.5        1.63      188      136           68
# 6    259   53    Male        125.1        1.91      171      137           70
# 7    604   37  Female         73.5        1.69      174      131           66
# 8    965   23  Female         44.1        1.62      196      122           58
# 9    157   50  Female         67.1        1.75      161      120           59
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df.reset_index(drop=True) #yeni oluşan data frame'de ekstra bir kolon açıp eski df'nin indexlerini görmememizi sağlar
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   47  Female         43.4        1.62      179      132           64
# 1   23  Female         64.5        1.70      187      125           72
# 2   25  Female         77.7        1.55      184      120           52
# 3   53    Male         61.0        1.63      170      124           74
# 4   50    Male        101.7        1.67      192      127           57
# 5   42    Male         73.5        1.63      188      136           68
# 6   53    Male        125.1        1.91      171      137           70
# 7   37  Female         73.5        1.69      174      131           66
# 8   23  Female         44.1        1.62      196      122           58
# 9   50  Female         67.1        1.75      161      120           59
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      0.51            303.0       Cardio            25.3
# ...

# %%
df = pd.read_csv("gym_members_exercise_tracking.csv")

# %%
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
df = df.nsmallest(10, "Calories_Burned").reset_index(drop=True)

# %%
df
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0   47  Female         43.4        1.62      179      132           64
# 1   23  Female         64.5        1.70      187      125           72
# 2   25  Female         77.7        1.55      184      120           52
# 3   53    Male         61.0        1.63      170      124           74
# 4   50    Male        101.7        1.67      192      127           57
# 5   42    Male         73.5        1.63      188      136           68
# 6   53    Male        125.1        1.91      171      137           70
# 7   37  Female         73.5        1.69      174      131           66
# 8   23  Female         44.1        1.62      196      122           58
# 9   50  Female         67.1        1.75      161      120           59
#
#    Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                      0.51            303.0       Cardio            25.3
# ...
